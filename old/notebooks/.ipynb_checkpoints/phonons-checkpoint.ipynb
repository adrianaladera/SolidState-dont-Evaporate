# %%
from phonopy import Phonopy as phon #heat capacity, entropy, etc
import phonopy
import os

# %%
os.getcwd()
# Out:
# '/pscratch/sd/a/aladera/phonons/inorganics_only'

# %%
ph = phonopy.load(supercell_filename="SPOSCAR")

# %%
ph.run_mesh([20,20,20])

# %%
ph.run_total_dos()

# %%
ph.auto_total_dos(plot=True).show()

# %%
ph.auto_band_structure(plot=True,ylim=[0,20]).show() #comp with ligands, are there imaginary modes?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 ph.auto_band_structure(plot=True,ylim=[0,20]).show()
#
# TypeError: Phonopy.auto_band_structure() got an unexpected keyword argument 'ylim'

# %%
ph.auto_band_structure(pl
