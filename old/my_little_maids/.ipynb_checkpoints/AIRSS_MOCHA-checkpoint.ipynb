# %%
from pymatgen.core import Structure
from pymatgen.io.vasp.sets import MPRelaxSet
import os
from ase.io import read, write
import numpy as np
from matplotlib import pyplot as plt
from ase import Atoms
import ase.build.attach as attach

# %%
def attach_hydrogens(path, file):
    '''
    - get length of all unit cell vectors, see which one is the longest
    - based on longest, check to see where the S/Se lies in relation to metal (i.e. above or below)
    - this will determine where relative to the inorganic structure that the H should be placed
    '''
    mocha = read(f"{path}{file}")
    ind_largest_v = np.argmax(mocha.get_cell().lengths()) # get index of largest unit cell vector
    dicked = {0:(1,0,0), 1:(0,1,0), 2:(0,0,1)}
    for atom in range(len(mocha)):
        if mocha.get_chemical_symbols()[atom] == 'S': # if is a chalcogen
            pos = np.array(mocha.get_positions()[atom])
            # print(pos)
            pos[ind_largest_v] += 1.3
            # print(f"{pos} YOUR MOM")
            H = Atoms('H', positions=[pos])
            mocha.extend(H)
    write(f"{path}{file[7:-9]}.vasp", mocha)
    print("Writing {}.vasp...".format(file[7:-9]))

    # mocha = attach.attach(mocha, H, distance=1, direction=dicked[ind_largest_v], maxiter=50, accuracy=1e-05)

    # print(mocha)

path = "/Users/adrianaladera/Desktop/MIT/research/MOChAs/airss/AgS_test/" 
file = "POSCAR_AgS-1176204-6340-3.res.vasp"
for file in os.listdir(path):
    if ".res.vasp" in file:
        attach_hydrogens(path, file)
txt = "POSCAR_AgS-1176204-6340-3.res.vasp"
txt[7:-9]
# Out:
# Writing AgS-1814254-6489-6.vasp...
# Writing AgS-1814254-6489-7.vasp...
# Writing AgS-1434444-5151-18.vasp...
# Writing AgS-949912-4923-7.vasp...
# Writing AgS-949912-4923-6.vasp...
# Writing AgS-1434444-5151-19.vasp...
# Writing AgS-1176204-6340-2.vasp...
# Writing AgS-1176204-6340-3.vasp...
# Writing AgS-1670427-4575-10.vasp...
# Writing AgS-1434444-5151-50.vasp...
# Writing AgS-1324131-5582-5.vasp...
# Writing AgS-1324131-5582-4.vasp...
# Writing AgS-1749721-825-4.vasp...
# Writing AgS-1749721-825-5.vasp...
# Writing AgS-1434444-5151-26.vasp...
# Writing AgS-1434444-5151-27.vasp...
# Writing AgS-1048508-1587-7.vasp...
# Writing AgS-1048508-1587-6.vasp...
# Writing AgS-1546968-9360-1.vasp...
# Writing AgS-1434444-5151-12.vasp...
# Writing AgS-1434444-5151-13.vasp...
# Writing AgS-1176204-6340-8.vasp...
# Writing AgS-1176204-6340-9.vasp...
# Writing AgS-1434444-5151-4.vasp...
# Writing AgS-1434444-5151-5.vasp...
# Writing AgS-1195946-1815-4.vasp...
# Writing AgS-1195946-1815-5.vasp...
# Writing AgS-1853131-5405-5.vasp...
# Writing AgS-1853131-5405-4.vasp...
# Writing AgS-1269613-4680-5.vasp...
# Writing AgS-1269613-4680-4.vasp...
# Writing AgS-1921436-773-5.vasp...
# Writing AgS-1921436-773-4.vasp...
# Writing AgS-1434444-5151-46.vasp...
# Writing AgS-1434444-5151-47.vasp...
# Writing AgS-926240-1420-4.vasp...
# Writing AgS-2026974-2739-2.vasp...
# Writing AgS-2026974-2739-3.vasp...
# Writing AgS-926240-1420-5.vasp...
# Writing AgS-1007873-9782-7.vasp...
# Writing AgS-1007873-9782-6.vasp...
# Writing AgS-959596-854-9.vasp...
# Writing AgS-959596-854-8.vasp...
# Writing AgS-1369044-9637-7.vasp...
# Writing AgS-1369044-9637-6.vasp...
# Writing AgS-1095449-2696-9.vasp...
# Writing AgS-1095449-2696-8.vasp...
# Writing AgS-1939942-3146-4.vasp...
# Writing AgS-1939942-3146-5.vasp...
# Writing AgS-1434444-5151-31.vasp...
# Writing AgS-1670427-4575-2.vasp...
# Writing AgS-1670427-4575-3.vasp...
# Writing AgS-1434444-5151-30.vasp...
# Writing AgS-1487158-8334-9.vasp...
# Writing AgS-1487158-8334-8.vasp...
# Writing AgS-959596-854-3.vasp...
# Writing AgS-959596-854-2.vasp...
# Writing AgS-2026974-2739-8.vasp...
# Writing AgS-2026974-2739-9.vasp...
# Writing AgS-1487158-8334-3.vasp...
# Writing AgS-1487158-8334-2.vasp...
# Writing AgS-1670427-4575-8.vasp...
# Writing AgS-1670427-4575-9.vasp...
# Writing AgS-1095449-2696-3.vasp...
# Writing AgS-1095449-2696-2.vasp...
# Writing AgS-1269613-4680-10.vasp...
# Writing AgS-1434444-5151-41.vasp...
# Writing AgS-1434444-5151-40.vasp...
# Writing AgS-2026974-2739-5.vasp...
# Writing AgS-926240-1420-3.vasp...
# Writing AgS-926240-1420-2.vasp...
# Writing AgS-2026974-2739-4.vasp...
# Writing AgS-1007873-9782-1.vasp...
# Writing AgS-1939942-3146-3.vasp...
# Writing AgS-1939942-3146-2.vasp...
# Writing AgS-1369044-9637-1.vasp...
# Writing AgS-1749721-825-10.vasp...
# Writing AgS-1670427-4575-5.vasp...
# Writing AgS-1434444-5151-36.vasp...
# Writing AgS-1434444-5151-37.vasp...
# Writing AgS-1670427-4575-4.vasp...
# Writing AgS-1921436-773-10.vasp...
# Writing AgS-959596-854-4.vasp...
# Writing AgS-959596-854-5.vasp...
# Writing AgS-926240-1420-9.vasp...
# Writing AgS-926240-1420-8.vasp...
# Writing AgS-1487158-8334-4.vasp...
# Writing AgS-1487158-8334-5.vasp...
# Writing AgS-1095449-2696-4.vasp...
# Writing AgS-1095449-2696-5.vasp...
# Writing AgS-1939942-3146-10.vasp...
# Writing AgS-1939942-3146-9.vasp...
# Writing AgS-1939942-3146-8.vasp...
# Writing AgS-1814254-6489-1.vasp...
# Writing AgS-949912-4923-1.vasp...
# Writing AgS-1176204-6340-5.vasp...
# Writing AgS-1176204-6340-4.vasp...
# Writing AgS-1434444-5151-9.vasp...
# Writing AgS-1434444-5151-8.vasp...
# Writing AgS-1814254-6489-10.vasp...
# Writing AgS-1195946-1815-9.vasp...
# Writing AgS-1195946-1815-8.vasp...
# Writing AgS-1048508-1587-10.vasp...
# Writing AgS-1749721-825-3.vasp...
# Writing AgS-1749721-825-2.vasp...
# Writing AgS-1269613-4680-8.vasp...
# Writing AgS-1434444-5151-21.vasp...
# Writing AgS-1434444-5151-20.vasp...
# Writing AgS-1269613-4680-9.vasp...
# Writing AgS-1324131-5582-2.vasp...
# Writing AgS-1324131-5582-3.vasp...
# Writing AgS-1921436-773-8.vasp...
# Writing AgS-1921436-773-9.vasp...
# Writing AgS-1048508-1587-1.vasp...
# Writing AgS-1546968-9360-6.vasp...
# Writing AgS-1546968-9360-7.vasp...
# Writing AgS-1176204-6340-10.vasp...
# Writing AgS-1853131-5405-8.vasp...
# Writing AgS-1853131-5405-9.vasp...
# Writing AgS-1434444-5151-3.vasp...
# Writing AgS-1434444-5151-2.vasp...
# Writing AgS-1195946-1815-3.vasp...
# Writing AgS-1195946-1815-2.vasp...
# Writing AgS-1434444-5151-15.vasp...
# Writing AgS-1434444-5151-14.vasp...
# Writing AgS-1853131-5405-2.vasp...
# Writing AgS-1853131-5405-3.vasp...
# Writing AgS-1324131-5582-10.vasp...
# Writing AgS-1921436-773-2.vasp...
# Writing AgS-1921436-773-3.vasp...
# Writing AgS-1324131-5582-8.vasp...
# Writing AgS-1324131-5582-9.vasp...
# Writing AgS-1749721-825-9.vasp...
# Writing AgS-1749721-825-8.vasp...
# Writing AgS-1269613-4680-2.vasp...
# Writing AgS-1269613-4680-3.vasp...
# Writing AgS-959596-854-1.vasp...
# Writing AgS-1487158-8334-1.vasp...
# Writing AgS-1434444-5151-38.vasp...
# Writing AgS-1434444-5151-39.vasp...
# Writing AgS-1095449-2696-1.vasp...
# Writing AgS-1007873-9782-4.vasp...
# Writing AgS-1007873-9782-5.vasp...
# Writing AgS-1369044-9637-10.vasp...
# Writing AgS-1434444-5151-45.vasp...
# Writing AgS-1434444-5151-44.vasp...
# Writing AgS-926240-1420-7.vasp...
# Writing AgS-2026974-2739-1.vasp...
# Writing AgS-926240-1420-6.vasp...
# Writing AgS-1369044-9637-4.vasp...
# Writing AgS-1369044-9637-5.vasp...
# Writing AgS-1939942-3146-7.vasp...
# Writing AgS-1939942-3146-6.vasp...
# Writing AgS-1434444-5151-32.vasp...
# Writing AgS-1670427-4575-1.vasp...
# Writing AgS-1434444-5151-33.vasp...
# Writing AgS-1434444-5151-11.vasp...
# Writing AgS-1434444-5151-10.vasp...
# Writing AgS-1434444-5151-7.vasp...
# Writing AgS-1434444-5151-6.vasp...
# Writing AgS-1195946-1815-7.vasp...
# Writing AgS-1195946-1815-6.vasp...
# Writing AgS-2026974-2739-10.vasp...
# Writing AgS-1546968-9360-8.vasp...
# Writing AgS-1546968-9360-9.vasp...
# Writing AgS-1853131-5405-6.vasp...
# Writing AgS-1853131-5405-7.vasp...
# Writing AgS-1269613-4680-6.vasp...
# Writing AgS-1269613-4680-7.vasp...
# Writing AgS-1921436-773-6.vasp...
# Writing AgS-1921436-773-7.vasp...
# Writing AgS-949912-4923-4.vasp...
# Writing AgS-949912-4923-5.vasp...
# Writing AgS-1176204-6340-1.vasp...
# Writing AgS-1814254-6489-5.vasp...
# Writing AgS-1814254-6489-4.vasp...
# Writing AgS-1195946-1815-10.vasp...
# Writing AgS-1324131-5582-6.vasp...
# Writing AgS-1324131-5582-7.vasp...
# Writing AgS-1749721-825-7.vasp...
# Writing AgS-1749721-825-6.vasp...
# Writing AgS-1434444-5151-25.vasp...
# Writing AgS-1434444-5151-24.vasp...
# Writing AgS-1048508-1587-4.vasp...
# Writing AgS-1048508-1587-5.vasp...
# Writing AgS-1546968-9360-2.vasp...
# Writing AgS-1546968-9360-3.vasp...
# Writing AgS-1487158-8334-10.vasp...
# Writing AgS-1434444-5151-1.vasp...
# Writing AgS-1195946-1815-1.vasp...
# Writing AgS-1853131-5405-10.vasp...
# Writing AgS-1814254-6489-8.vasp...
# Writing AgS-1814254-6489-9.vasp...
# Writing AgS-949912-4923-9.vasp...
# Writing AgS-1434444-5151-16.vasp...
# Writing AgS-1546968-9360-10.vasp...
# Writing AgS-1434444-5151-17.vasp...
# Writing AgS-949912-4923-8.vasp...
# Writing AgS-1853131-5405-1.vasp...
# Writing AgS-1048508-1587-9.vasp...
# Writing AgS-1048508-1587-8.vasp...
# Writing AgS-1921436-773-1.vasp...
# Writing AgS-1269613-4680-1.vasp...
# Writing AgS-1434444-5151-28.vasp...
# Writing AgS-1434444-5151-29.vasp...
# Writing AgS-949912-4923-3.vasp...
# Writing AgS-949912-4923-2.vasp...
# Writing AgS-1095449-2696-10.vasp...
# Writing AgS-1176204-6340-6.vasp...
# Writing AgS-1176204-6340-7.vasp...
# Writing AgS-1814254-6489-2.vasp...
# Writing AgS-1814254-6489-3.vasp...
# Writing AgS-1749721-825-1.vasp...
# Writing AgS-1434444-5151-22.vasp...
# Writing AgS-1434444-5151-23.vasp...
# Writing AgS-959596-854-10.vasp...
# Writing AgS-1324131-5582-1.vasp...
# Writing AgS-1048508-1587-3.vasp...
# Writing AgS-1048508-1587-2.vasp...
# Writing AgS-1546968-9360-5.vasp...
# Writing AgS-1546968-9360-4.vasp...
# Writing AgS-959596-854-7.vasp...
# Writing AgS-959596-854-6.vasp...
# Writing AgS-1434444-5151-48.vasp...
# Writing AgS-1434444-5151-49.vasp...
# Writing AgS-1007873-9782-9.vasp...
# Writing AgS-1007873-9782-8.vasp...
# Writing AgS-926240-1420-10.vasp...
# Writing AgS-1487158-8334-7.vasp...
# Writing AgS-1487158-8334-6.vasp...
# Writing AgS-1369044-9637-9.vasp...
# Writing AgS-1369044-9637-8.vasp...
# Writing AgS-1095449-2696-7.vasp...
# Writing AgS-1095449-2696-6.vasp...
# Writing AgS-1007873-9782-3.vasp...
# Writing AgS-1007873-9782-2.vasp...
# Writing AgS-1007873-9782-10.vasp...
# Writing AgS-1434444-5151-42.vasp...
# Writing AgS-1434444-5151-43.vasp...
# Writing AgS-2026974-2739-6.vasp...
# Writing AgS-926240-1420-1.vasp...
# Writing AgS-2026974-2739-7.vasp...
# Writing AgS-1939942-3146-1.vasp...
# Writing AgS-1369044-9637-3.vasp...
# Writing AgS-1369044-9637-2.vasp...
# Writing AgS-1670427-4575-6.vasp...
# Writing AgS-1434444-5151-35.vasp...
# Writing AgS-1434444-5151-34.vasp...
# Writing AgS-1670427-4575-7.vasp...
# 'AgS-1176204-6340-3'

# %%
PATH = "/home/amansour/Documents/Projects/MOChA/AIRSS/"
os.chdir(PATH)

# %%
# checking the convergence after each step
def check_convergence(PATH, ionic_steps, structures):
    '''ionic_steps - number of steps (AIRSS needs only 3 or 4 steps, considered "converged")'''
    for i in range(len(structures)):
        os.chdir(PATH + "struc_{}".format(i))
        with open("out", "r") as f:
            lines = f.readlines()
            for line in lines:
                if f"{ionic_steps} F=" in line:
                    #list of structures that are converged
                    struc_converged = []
                    struc_converged.append(structures[i])
                else:
                    # write to a file the structure that is not converged
                    with open("not_converged", "w") as f:
                        struc_not_converged = f"struc_{i}_not_converged"
                        f.write(struc_not_converged + "\n")
        os.chdir(PATH)
        return struc_converged

# %%
# read all the .vasp files in the directory and save them as structures
structures = []
for file in os.listdir(PATH):
    if file.endswith(".vasp"):
        structures.append(Structure.from_file(file))

# %%
incar_settings_1 = {"NELMIN": 5, "ALGO": 'Normal', "ISPIN": 1, "ISMEAR": 0, "NSW": 4, "ENCUT": 600, "EDIFF" : 1e-4, "EDIFFG" : -0.001, "KPAR": 1, "NCORE": 32, "SIGMA" : 0.01, "NELM" : 150}  # user custom incar settings
incar_settings_2 = {"NELMIN": 5, "ALGO": 'Normal', "ISPIN": 1, "ISMEAR": 0, "NSW": 20, "ENCUT": 700, "EDIFF" : 1e-6, "EDIFFG" : -0.001, "KPAR": 1, "NCORE": 32, "SIGMA" : 0.01}  # user custom incar settings

# %%
# use MPRelaxSet to generate the input files for all the structures - 

for i in range(len(structures)):
    relax = MPRelaxSet(structures[i], user_incar_settings=incar_settings_1)
    relax.write_input("struc_{}".format(i), potcar_spec=True)
# remove POTCAR spec (fake potcar)

# %%
# run the calculations

for i in range(len(structures)):
    os.chdir(PATH + "struc_{}".format(i))
    os.system("vrun 1 32")
    os.chdir(PATH)

# %%
# after the first step is done check the convergence of the calculations
# For the calcualtions that are converged run the second step - converged_calcs is a list of the structures that are converged
# Also we want to copy CONTCAR to POSCAR for the next step - keep the POSCAR as POSCAR_1 as a file

import time

for j in range(0,4):
    # add a sleep time of 4 hours to the loop
    time.sleep(14400)
    converged_calcs = check_convergence(PATH, 4, structures)
    for i in range(len(converged_calcs)):
        os.chdir(PATH + f"struc_{converged_calcs[i]}")
        os.system("cp CONTCAR POSCAR")
        os.system("cp CONTCAR POSCAR_{}".format(j+1))
        os.system("vrun 1 32")
        os.chdir(PATH)

# This will need to be modified depending on how we end up submiting the calculations/workflow

# %%
# now we check the convergence again and run the incar_settings_2

converged_calcs = check_convergence(PATH, 4, structures)

for i in range(len(converged_calcs)):
    os.chdir(PATH + f"struc_{converged_calcs[i]}")
    os.system("cp CONTCAR POSCAR_4") # to keep a record
    #poscar_new = (Structure.from_file("CONTCAR"))
    relax_2 = MPRelaxSet.from_prev_calc(".", user_incar_settings=incar_settings_2)
    relax_2.write_input("r2_struc_{}".format(i), potcar_spec=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 # now we check the convergence again and run the incar_settings_2
# ----> 3 converged_calcs = check_convergence(PATH, 4, structures)
#       5 for i in range(len(converged_calcs)):
#       6     os.chdir(PATH + f"struc_{converged_calcs[i]}")
#
# Cell In[11], line 5, in check_convergence(PATH, ionic_steps, structures)
#       3 for i in range(len(structures)):
#       4     os.chdir(PATH + "struc_{}".format(i))
# ----> 5     with open("out", "r") as f:
#       6         lines = f.readlines()
#       7         for line in lines:
#
# File ~/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'out'

# %%
# We need to get the energies of the structures that are converged and rank them from lowest to highest
from pymatgen.io.vasp import Vasprun

converged_calcs = check_convergence(PATH, 20, structures)

for i in range(len(converged_calcs)):
    energies = []
    os.chdir(PATH + f"struc_{converged_calcs[i]}" + f"r2_struc_{converged_calcs[i]}") # need to change this to the correct path
    energy = Vasprun("vasprun.xml").final_energy #write energy of each structure
    energies.append(energy)

# now match the energy list and the structure name as a dataframe and sort the energies from lowest to highest

import pandas as pd

df = pd.DataFrame(list(zip(converged_calcs, energies)), columns = ["structure", "energy"])
df.sort_values(by=["energy"], inplace=True)
#more proper relaxations after analysis
